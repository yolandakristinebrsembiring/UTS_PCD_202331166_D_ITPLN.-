# %% [markdown]
# ## IMPORT LIBRARY

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
img = cv2.imread ('coloring.jpg')

# %%
(baris, kolom)= img_rgb.shape[:2]

# %%
r = color_image[:, :, 0] 
g = color_image[:, :, 1] 
b = color_image[:, :, 2]  

f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 10)) 

ax1.set_title('Citra Kontras') 
ax1.imshow(color_image) 
ax1.axis('off') 

ax2.set_title('Merah') 
ax2.imshow(r, cmap="gray")  
ax2.axis('on')

ax3.set_title('Hijau') 
ax3.imshow(g, cmap="gray") 
ax3.axis('on')

ax4.set_title('Biru')
ax4.imshow(b, cmap="gray")
ax4.axis('on')
# Out:
# (-0.5, 3539.5, 1751.5, -0.5)

# %%
b, g, r = cv2.split(img)

plt.figure(figsize=(20, 5))

plt.subplot(141)
plt.hist(r.ravel(), bins=256, color='red', range=[0,256], alpha=0.7)
plt.title('Histogram Merah')
plt.xlabel('Intensitas')
plt.ylabel('Jumlah Piksel')


plt.subplot(142)
plt.hist(g.ravel(), bins=256, color='green', range=[0,256], alpha=0.7)
plt.title('Histogram Hijau')
plt.xlabel('Intensitas')

plt.subplot(143)
plt.hist(b.ravel(), bins=256, color='blue', range=[0,256], alpha=0.7)
plt.title('Histogram Biru')
plt.xlabel('Intensitas')
# Out:
# Text(0.5, 0, 'Intensitas')
